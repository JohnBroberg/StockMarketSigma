# %% [markdown]
# # Stock Market (S&P 500) Sigma (standard deviation) Analysis

# %%
#created by John Broberg on 2022-05-29
#inspired by "LET THE WILD RUMPUS BEGIN" by JEREMY GRANTHAM of GMO
#ref. https://www.gmo.com/globalassets/articles/viewpoints/2022/gmo_let-the-wild-rumpus-begin_1-22.pdf

#https://www.gmo.com/americas/research-library/entering-the-superbubbles-final-act/
#"...superbubbles – 2.5 to 3 sigma events..."
#"...ordinary 2 sigma bubbles..."
#"Ordinary bubbles are, to us, those that reach a 2 sigma deviation from trend. Superbubbles reach 2.5 sigma or greater."

#source data: https://fred.stlouisfed.org/series/SP500

#cd
#cd git/StockMarketSigma
#git pull https://github.com/JohnBroberg/StockMarketSigma.git

#Get trendline equation
#https://stackoverflow.com/questions/49460596/add-trendline-with-equation-in-2d-array
#https://stackoverflow.com/questions/26447191/how-to-add-trendline-in-python-matplotlib-dot-scatter-graphs


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = 'SP500.csv'
df = pd.read_csv(data)

df
# Out:
#      observation_date    SP500
# 0          2016-09-22  2177.18
# 1          2016-09-23  2164.69
# 2          2016-09-26  2146.10
# 3          2016-09-27  2159.93
# 4          2016-09-28  2171.37
# ...               ...      ...
# 2603       2026-09-15  7585.73
# 2604       2026-09-16  7551.81
# 2605       2026-09-17  7637.76
# 2606       2026-09-18  7650.50
# 2607       2026-09-21  7764.70
#
# [2608 rows x 2 columns]

# %% [markdown]
# ## Data Loading & Setup
#
# Load the S&P 500 historical data and describe dataset.

# %%
df = df.rename(columns={"observation_date": "Date"})

# %%
df.describe()
# Out:
#              SP500
# count  2512.000000
# mean   4141.799232
# std    1478.891718
# min    2085.180000
# 25%    2839.220000
# 50%    3966.845000
# 75%    5080.745000
# max    7798.990000

# %% [markdown]
# ## Data Cleaning & Preparation
#
# Remove missing values and prepare the dataset for analysis.

# %%
#remove holidays (Open == 0)
# Drop rows where SP500 is missing
df = df.dropna(subset=["SP500"])

# Optional: Reset index if needed
df.reset_index(drop=True, inplace=True)
df.describe()
# Out:
#              SP500
# count  2512.000000
# mean   4141.799232
# std    1478.891718
# min    2085.180000
# 25%    2839.220000
# 50%    3966.845000
# 75%    5080.745000
# max    7798.990000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2512 non-null   object
#  1   SP500   2512 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 39.4+ KB

# %%
df.shape
# Out:
# (2512, 2)

# %%
df.isnull().any()
# Out:
# Date     False
# SP500    False
# dtype: bool

# %%
sns.set()

plt.hist(df['SP500'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Statistical Analysis
#
# Calculate key metrics: mean and standard deviation.

# %%
close_current = df['SP500'].iloc[-1]
close_current
# Out:
# np.float64(7764.7)

# %%
close_mean = df['SP500'].mean()
close_mean
# Out:
# np.float64(4141.799231687899)

# %%
close_sd = df['SP500'].std()
close_sd
# Out:
# 1478.891718393603

# %%
sigma1 = close_mean + close_sd
sigma1
# Out:
# np.float64(5620.690950081502)

# %%
sigma2 = close_mean + (2 * close_sd)  #bubble (from trend) according to Grantham
sigma2
# Out:
# np.float64(7099.582668475105)

# %%
sigma2_5 = close_mean + (2.5 * close_sd)  #super bubble (from trend) according to Grantham
sigma2_5
# Out:
# np.float64(7839.028527671906)

# %%
cols = ['Date','SP500']
df1 = df.loc[:,cols]
df1['Date'] = pd.to_datetime(df1['Date'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2512 non-null   datetime64[ns]
#  1   SP500   2512 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 39.4 KB

# %%
#Date Range
date_start = min(df1['Date']).date()
date_end = max(df1['Date']).date()

# %% [markdown]
# ## Visualization
#
# Create visual representations of the S&P 500 data against statistical thresholds.

# %%
#Daily S&P 500 Close/Last, vs mean and standard deviations

if close_current > sigma2:
    c = 'red'
elif close_current > sigma1:
    c = 'orange'
else: 
    c = 'green'

df1.plot(x='Date', y='SP500', color = c)
plt.axhline(close_mean, color='black', label='Mean')
plt.axhline(sigma1, color='black', linestyle='--', label='+1 standard deviation')
plt.axhline(sigma2, color='black', linestyle=':', label='+2 standard deviations')
plt.legend()
plt.title(f'S&P 500 Daily Close/Last - {date_start} to {date_end}')
# Out:
# Text(0.5, 1.0, 'S&P 500 Daily Close/Last - 2016-09-22 to 2026-09-21')

# %%
# Using Kernal Density Estimation (kde) to approximate probability density function
# https://seaborn.pydata.org/tutorial/distributions.html #kernel-density-estimation
#bw_adjust: adjust bandwidth to smoothe out modalities

sns.displot(df1['SP500'], kind='kde', bw_adjust=3.0) 

plt.axvline(close_current, color=c, label='Close/Last')
plt.axvline(close_mean, color='black', label='Mean')
plt.axvline(sigma1, color='black', linestyle='--', label='+1 standard deviations')
plt.axvline(sigma2, color='black', linestyle=':', label='+2 standard deviations')
plt.legend(loc='upper left')
plt.title(f'Density: S&P 500 Daily Close/Last - {date_start} to {date_end}')
# Out:
# Text(0.5, 1.0, 'Density: S&P 500 Daily Close/Last - 2016-09-22 to 2026-09-21')

# %%
z_score = (close_current - close_mean)/close_sd
z_score
# Out:
# np.float64(2.4497403854876922)

# %%
# https://realpython.com/linear-regression-in-python/
#Step 4: Get results
